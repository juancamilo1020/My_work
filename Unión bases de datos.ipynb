# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Base_Gesproy_15012021.xlsx')

# %%
df['comas'] = df['Municipios beneficiarios'].str.count(',').add(1)

# %%
df
# Out:
#                 BPIN                                        NOMBRE OCAD  \
# 0      2012000060032                                  Región Centro Sur
# 1      2012000060033                                  Región Centro Sur
# 2      2012000100057  Departamento Administrativo de la Ciencia, la ...
# 3      2012000100158  Departamento Administrativo de la Ciencia, la ...
# 4      2012000100174  Departamento Administrativo de la Ciencia, la ...
# ...              ...                                                ...
# 20173  2019000100013  Departamento Administrativo de la Ciencia, la ...
# 20174  2019000100035  Departamento Administrativo de la Ciencia, la ...
# 20175  2019000100011  Departamento Administrativo de la Ciencia, la ...
# 20176  2019000100038  Departamento Administrativo de la Ciencia, la ...
# 20177  2019000100015  Departamento Administrativo de la Ciencia, la ...
#
#                   TIPO OCAD REGIÓN PND ENTIDAD MAYORES RECURSOS        REGIÓN  \
# ...

# %%
for i, value in enumerate(df['comas'].values):
            if np.isnan(value):
                df['comas'][i] = 1
# Out:
# <ipython-input-184-27f2b4cc5a6a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comas'][i] = 1

# %%
df
# Out:
#                 BPIN                                        NOMBRE OCAD  \
# 0      2012000060032                                  Región Centro Sur
# 1      2012000060033                                  Región Centro Sur
# 2      2012000100057  Departamento Administrativo de la Ciencia, la ...
# 3      2012000100158  Departamento Administrativo de la Ciencia, la ...
# 4      2012000100174  Departamento Administrativo de la Ciencia, la ...
# ...              ...                                                ...
# 20173  2019000100013  Departamento Administrativo de la Ciencia, la ...
# 20174  2019000100035  Departamento Administrativo de la Ciencia, la ...
# 20175  2019000100011  Departamento Administrativo de la Ciencia, la ...
# 20176  2019000100038  Departamento Administrativo de la Ciencia, la ...
# 20177  2019000100015  Departamento Administrativo de la Ciencia, la ...
#
#                   TIPO OCAD REGIÓN PND ENTIDAD MAYORES RECURSOS        REGIÓN  \
# ...

# %%
comas = df['comas']
newdf = pd.DataFrame(np.repeat(df.values,comas,axis=0))
newdf.columns = df.columns
newdf
# Out:
#                 BPIN                                        NOMBRE OCAD  \
# 0      2012000060032                                  Región Centro Sur
# 1      2012000060033                                  Región Centro Sur
# 2      2012000100057  Departamento Administrativo de la Ciencia, la ...
# 3      2012000100158  Departamento Administrativo de la Ciencia, la ...
# 4      2012000100174  Departamento Administrativo de la Ciencia, la ...
# ...              ...                                                ...
# 21783  2019000100013  Departamento Administrativo de la Ciencia, la ...
# 21784  2019000100035  Departamento Administrativo de la Ciencia, la ...
# 21785  2019000100011  Departamento Administrativo de la Ciencia, la ...
# 21786  2019000100038  Departamento Administrativo de la Ciencia, la ...
# 21787  2019000100015  Departamento Administrativo de la Ciencia, la ...
#
#                   TIPO OCAD REGIÓN PND ENTIDAD MAYORES RECURSOS        REGIÓN  \
# ...

# %%
newdf['comas'] = newdf['Municipios beneficiarios'].str.count(',').add(1)

# %%
newdf
# Out:
#                 BPIN                                        NOMBRE OCAD  \
# 0      2012000060032                                  Región Centro Sur
# 1      2012000060033                                  Región Centro Sur
# 2      2012000100057  Departamento Administrativo de la Ciencia, la ...
# 3      2012000100158  Departamento Administrativo de la Ciencia, la ...
# 4      2012000100174  Departamento Administrativo de la Ciencia, la ...
# ...              ...                                                ...
# 21783  2019000100013  Departamento Administrativo de la Ciencia, la ...
# 21784  2019000100035  Departamento Administrativo de la Ciencia, la ...
# 21785  2019000100011  Departamento Administrativo de la Ciencia, la ...
# 21786  2019000100038  Departamento Administrativo de la Ciencia, la ...
# 21787  2019000100015  Departamento Administrativo de la Ciencia, la ...
#
#                   TIPO OCAD REGIÓN PND ENTIDAD MAYORES RECURSOS        REGIÓN  \
# ...

# %%
newdf['mun1'] = ''
newdf['mun2'] = ''
newdf['mun3'] = ''
newdf['mun4'] = ''
newdf['mun5'] = ''
newdf['mun6'] = ''
newdf['mun7'] = ''
newdf['mun8'] = ''
newdf['mun9'] = ''
newdf['mun10'] = ''
newdf['mun11'] = ''
newdf['mun12'] = ''
newdf['mun13'] = ''

# %%
for i, value in enumerate(newdf['comas'].values):
    if newdf['comas'][i] == 1:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
    elif newdf['comas'][i] == 2:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
    elif newdf['comas'][i] == 3:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
    elif newdf['comas'][i] == 4:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
    elif newdf['comas'][i] == 5:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:]
    elif newdf['comas'][i] == 6:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]     
    elif newdf['comas'][i] == 7:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]     
    elif newdf['comas'][i] == 8:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]  
        newdf['mun8'][i] = newdf['Municipios beneficiarios'][i].split(',')[7][1:]  
    elif newdf['comas'][i] == 9:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]  
        newdf['mun8'][i] = newdf['Municipios beneficiarios'][i].split(',')[7][1:]  
        newdf['mun9'][i] = newdf['Municipios beneficiarios'][i].split(',')[8][1:]  
    elif newdf['comas'][i] == 10:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]  
        newdf['mun8'][i] = newdf['Municipios beneficiarios'][i].split(',')[7][1:]  
        newdf['mun9'][i] = newdf['Municipios beneficiarios'][i].split(',')[8][1:] 
        newdf['mun10'][i] = newdf['Municipios beneficiarios'][i].split(',')[9][1:] 
    elif newdf['comas'][i] == 11:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]  
        newdf['mun8'][i] = newdf['Municipios beneficiarios'][i].split(',')[7][1:]  
        newdf['mun9'][i] = newdf['Municipios beneficiarios'][i].split(',')[8][1:] 
        newdf['mun10'][i] = newdf['Municipios beneficiarios'][i].split(',')[9][1:] 
        newdf['mun11'][i] = newdf['Municipios beneficiarios'][i].split(',')[10][1:] 
    elif newdf['comas'][i] == 12:
        newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
        newdf['mun2'][i] = newdf['Municipios beneficiarios'][i].split(',')[1][1:]
        newdf['mun3'][i] = newdf['Municipios beneficiarios'][i].split(',')[2][1:]
        newdf['mun4'][i] = newdf['Municipios beneficiarios'][i].split(',')[3][1:]
        newdf['mun5'][i] = newdf['Municipios beneficiarios'][i].split(',')[4][1:] 
        newdf['mun6'][i] = newdf['Municipios beneficiarios'][i].split(',')[5][1:]
        newdf['mun7'][i] = newdf['Municipios beneficiarios'][i].split(',')[6][1:]  
        newdf['mun8'][i] = newdf['Municipios beneficiarios'][i].split(',')[7][1:]  
        newdf['mun9'][i] = newdf['Municipios beneficiarios'][i].split(',')[8][1:] 
        newdf['mun10'][i] = newdf['Municipios beneficiarios'][i].split(',')[9][1:] 
        newdf['mun11'][i] = newdf['Municipios beneficiarios'][i].split(',')[10][1:] 
        newdf['mun12'][i] = newdf['Municipios beneficiarios'][i].split(',')[11][1:]
# Out:
# <ipython-input-190-90bfa4584921>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
# <ipython-input-190-90bfa4584921>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['mun1'][i] = newdf['Municipios beneficiarios'][i].split(',')[0]
# <ipython-input-190-90bfa4584921>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
newdf.rename(columns={"Columna1": "Municipio beneficiario"}, inplace=True)

# %%
newdf['conteo'] = newdf.groupby('BPIN').cumcount() + 1

# %%
for i in range(len(newdf)):
    if newdf['comas'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 2 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 2 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i]
    elif newdf['comas'][i] == 3 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 3 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 3 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 4 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 4 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 4 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 4 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 5 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 5 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 5 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 5 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 5 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 6 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 7 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 8 and newdf['conteo'][i] == 8:
        newdf['Municipio beneficiario'][i] = newdf['mun8'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 8:
        newdf['Municipio beneficiario'][i] = newdf['mun8'][i]
    elif newdf['comas'][i] == 9 and newdf['conteo'][i] == 9:
        newdf['Municipio beneficiario'][i] = newdf['mun9'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 8:
        newdf['Municipio beneficiario'][i] = newdf['mun8'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 9:
        newdf['Municipio beneficiario'][i] = newdf['mun9'][i]
    elif newdf['comas'][i] == 10 and newdf['conteo'][i] == 10:
        newdf['Municipio beneficiario'][i] = newdf['mun10'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 8:
        newdf['Municipio beneficiario'][i] = newdf['mun8'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 9:
        newdf['Municipio beneficiario'][i] = newdf['mun9'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 10:
        newdf['Municipio beneficiario'][i] = newdf['mun10'][i]
    elif newdf['comas'][i] == 11 and newdf['conteo'][i] == 11:
        newdf['Municipio beneficiario'][i] = newdf['mun11'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 1:
        newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 2:
        newdf['Municipio beneficiario'][i] = newdf['mun2'][i] 
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 3:
        newdf['Municipio beneficiario'][i] = newdf['mun3'][i] 
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 4:
        newdf['Municipio beneficiario'][i] = newdf['mun4'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 5:
        newdf['Municipio beneficiario'][i] = newdf['mun5'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 6:
        newdf['Municipio beneficiario'][i] = newdf['mun6'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 7:
        newdf['Municipio beneficiario'][i] = newdf['mun7'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 8:
        newdf['Municipio beneficiario'][i] = newdf['mun8'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 9:
        newdf['Municipio beneficiario'][i] = newdf['mun9'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 10:
        newdf['Municipio beneficiario'][i] = newdf['mun10'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 11:
        newdf['Municipio beneficiario'][i] = newdf['mun11'][i]
    elif newdf['comas'][i] == 12 and newdf['conteo'][i] == 12:
        newdf['Municipio beneficiario'][i] = newdf['mun12'][i]
# Out:
# <ipython-input-239-ed0660d7f111>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
# <ipython-input-239-ed0660d7f111>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Municipio beneficiario'][i] = newdf['mun1'][i]
# <ipython-input-239-ed0660d7f111>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Municipio beneficiario'][i] = newdf['mun2'][i]
# ...

# %%
newdf.to_excel('/Users/juancamiloperdomo/Documents/CNC/ADS-SGR/Base.xlsx', index = False)

# %%
municipios = pd.read_excel('Base_municipios.xlsx')

# %%
municipios
# Out:
#      Departamento2       Municipio  Codigo2
# 0        Antioquia        MEDELLIN     5001
# 1        Antioquia       ABEJORRAL     5002
# 2        Antioquia        ABRIAQUI     5004
# 3        Antioquia      ALEJANDRIA     5021
# 4        Antioquia           AMAGA     5030
# ...            ...             ...      ...
# 1107        Vaupes         TARAIRA    97666
# 1108       Vichada  PUERTO CARREÑO    99001
# 1109       Vichada    LA PRIMAVERA    99524
# 1110       Vichada   SANTA ROSALIA    99624
# 1111       Vichada        CUMARIBO    99773
#
# [1112 rows x 3 columns]
